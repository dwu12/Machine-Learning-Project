# %% [markdown]
# # Word Embeddings
#
# In this notebook, you will implement 2 algorithms for learning word embeddings. You will use these algorithms to measure semantic similarity between words.

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

## Standard Library
import random
from string import punctuation
from collections import Counter

## External Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_distances
from sklearn.datasets import fetch_20newsgroups
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
import gensim.downloader

# PyTorch Modules: see http://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)
print("GPU Available:", torch.cuda.is_available())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# GPU Available: True

# %%
## Simple Plotting Utility
def showPlot(title, *args):
    plt.figure()
    fig, ax = plt.subplots()
    for a in args:
      _ = ax.plot(a)
    _ = ax.set_title(title)

# %%
def tokenize(text):
    """
    Simple tokenizer (sentences and then words)
    """
    sentences = sent_tokenize(text)
    examples = []
    for sentence in sentences:
        sentence = "".join(char for char in sentence if char not in punctuation)
        sentence = "".join(char for char in sentence if not char.isdigit())
        sentence = sentence.lower()
        tokens = word_tokenize(sentence)
        examples.append(tokens)
    return examples

tokenize("Why, hello there! What's your name?")
# Out:
# [['why', 'hello', 'there'], ['whats', 'your', 'name']]

# %% [markdown]
# ### Data
#
# We provide two datasets. Use the small dataset to develop your algorithms and test semantic similarity at the end of the notebook. Use the larger dataset once your models are developed to get a sense for the scalability of your approaches.
#
# Please include visualizations of the train/test loss for both datasets. For the small dataset, please train your models for 1000 epochs. For the large dataset, please train your models for at least 100 epochs.

# %%
# Text is lightly adapted (removing punctuation and possesives) from The Raven by Edgar Allan Poe
text_small = [""" Once upon a midnight dreary while I pondered weak and weary
 Over many a quaint and curious volume of forgotten lore
 While I nodded nearly napping suddenly there came a tapping
 As of some one gently rapping rapping at my chamber door
 This is some visiter I muttered tapping at my chamber door
                          Only this and nothing more

 Ah distinctly I remember it was in the bleak December
 And each separate dying ember wrought its ghost upon the floor
 Eagerly I wished the morrow vainly I had sought to borrow
 From my books surcease of sorrow sorrow for the lost Lenore
 For the rare and radiant maiden whom the angels name Lenore
                          Nameless here for evermore

 And the silken sad uncertain rustling of each purple curtain
 Thrilled me filled me with fantastic terrors never felt before
 So that now to still the beating of my heart I stood repeating
 This is some visiter entreating entrance at my chamber door
 Some late visiter entreating entrance at my chamber door
                          This it is and nothing more

 Presently my soul grew stronger hesitating then no longer
 Sir said I or Madam truly your forgiveness I implore
 But the fact is I was napping and so gently you came rapping
 And so faintly you came tapping tapping at my chamber door
 That I scarce was sure I heard you here I opened wide the door
                          Darkness there and nothing more

 Deep into that darkness peering long I stood there wondering fearing
 Doubting dreaming dreams no mortal ever dared to dream before
 But the silence was unbroken and the darkness gave no token
 And the only word there spoken was the whispered word Lenore
 This I whispered and an echo murmured back the word Lenore
                          Merely this and nothing more

 Back into the chamber turning all my soul within me burning
 Soon I heard again a tapping somewhat louder than before
 Surely said I surely that is something at my window lattice
 Let me see then what thereat is and this mystery explore
 Let my heart be still a moment and this mystery explore
                          This is the wind and nothing more

 And my soul from out that shadow that lies floating on the floor
                          Shall be lifted nevermore"""]

# %%
## Retrieve/Load Data
data = fetch_20newsgroups(subset="test", ## Choose Test Since Full Dataset Will Take Significant Training Time                         
                          remove=("headers","footers","quotes"),
                          data_home="./data/",
                          download_if_missing=True,
                          shuffle=False)

## Isolate Data
text_large = data.data
labels = data.target

## Show Sample Newsgroups Data
show = lambda i: print(text_large[i], "\n", tokenize(text_large[i]))
show(30)
# Out:
# It wasn't Jesus who changed the rules of the game (see quote above),
# it was Paul.
#
# Cheers,
# Kent
#
#  [['it', 'wasnt', 'jesus', 'who', 'changed', 'the', 'rules', 'of', 'the', 'game', 'see', 'quote', 'above', 'it', 'was', 'paul'], ['cheers', 'kent']]

# %%
## Tokenize Data (We Recommend Developing your model using text_small first)
documents = list(map(tokenize, text_small))
#documents = list(map(tokenize, text_large))

## Flatten Sentences
documents = [tokens for d in documents for tokens in d]
print("Dataset Size:", len(documents))
# Out:
# Dataset Size: 1

# %%
## Choose Frequency and Top Word Removal (Should Change This Depending on the Dataset)
MIN_FREQ = 0
RM_TOP = 0

## Get Vocabulary
vocab = [t for document in documents for t in document]
vocab_counts = Counter(vocab)
stopwords = set([s[0] for s in vocab_counts.most_common(RM_TOP)])
vocab = set([v for v in set(vocab) if vocab_counts[v] >= MIN_FREQ and v not in stopwords] + ["EOS"])
vocab_size = len(vocab)
print("Vocab Size:", vocab_size)

# Build a dictionary so that each word in vocabualary is assigned a number and 
# and we can map each number back to the word
w2i = {w: i for i, w in enumerate(sorted(vocab))}
i2w = {i: w for i, w in enumerate(sorted(vocab))}
# Out:
# Vocab Size: 435

# %%
## Update The Documents with OOV Token
documents = [list(filter(lambda token: token in vocab, document)) for document in documents]

## Sample Training And Test Documents
np.random.seed(1)
documents_train = documents_test = documents
if len(documents) > 1:
    train_ind, test_ind = train_test_split(list(range(len(documents))))
    documents_train = [documents[t] for t in train_ind]
    documents_test = [documents[t] for t in test_ind]

# %% [markdown]
# ![Continuous bag of words vs. skipgram model](https://raw.githubusercontent.com/jojonki/word2vec-pytorch/master/word2vec.PNG)
#
# Image from https://github.com/jojonki/word2vec-pytorch

# %% [markdown]
# ## CBOW Implementation
#
# Fill in the TODOs below.

# %%
## Choose Context Size
CONTEXT_SIZE = 2

# Tuple of an array of words (the context) to a word (the target)
def create_cbow_dataset(documents, context_size):
    data = []
    for document in documents:
        ## Pad the sentence
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        ## Get Context Tokens
        for i in range(context_size, len(document) - context_size):
            target = document[i]
            before_ctx = []
            after_ctx = []
            for j in range(1,context_size+1):
                before_ctx.append(document[i - j])
                after_ctx.append(document[i + j])
            context = before_ctx + after_ctx
            data.append((context, target))
    return data

## Generate Datasets
cbow_train = create_cbow_dataset(documents_train, context_size=CONTEXT_SIZE)
cbow_test = create_cbow_dataset(documents_test, context_size=CONTEXT_SIZE)

## Show Samples
print('cbow train samples')
for i in range(5):
    print(cbow_train[i])
print("total train samples", len(cbow_train))
print("total test samples", len(cbow_test))
# Out:
# cbow train samples
# (['EOS', 'EOS', 'upon', 'a'], 'once')
# (['once', 'EOS', 'a', 'midnight'], 'upon')
# (['upon', 'once', 'midnight', 'dreary'], 'a')
# (['a', 'upon', 'dreary', 'while'], 'midnight')
# (['midnight', 'a', 'while', 'i'], 'dreary')
# total train samples 1090
# total test samples 1090

# %%
## Example of the Dataset Generator
create_cbow_dataset([["hello","there","my","friend"]], 2)
# Out:
# [(['EOS', 'EOS', 'there', 'my'], 'hello'),
#  (['hello', 'EOS', 'my', 'friend'], 'there'),
#  (['there', 'hello', 'friend', 'EOS'], 'my'),
#  (['my', 'there', 'EOS', 'EOS'], 'friend')]

# %%
## Helper Function to Construct Batches of Examples
def get_cbow_batches(data, batch_size):
    """
    Generate batches of data for training CBOW Model
    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        context, target = data[indice]
        ctx_idxs = [w2i[w] for w in context]
        ctx_var = torch.LongTensor(ctx_idxs)
        current_batch.append((ctx_var, torch.LongTensor([w2i[target]])))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_context = torch.stack([v[0] for v in current_batch])
            batch_target = torch.stack([v[1] for v in current_batch])
            current_batch = []
            yield batch_context, batch_target

# %%
# Simple 3 layer network to map target word to an array of probabilities for 
# each word being in its context
# Note that the first layer is a special layer - an embedding layer 
# It maps the one-hot encoded vocabulary to a vector of a fixed size 
class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        #TODO implement layers show in the picture above
        # self.model = nn.Sequential(
        #     nn.Embedding(vocab_size, embd_size),
        #     nn.Linear(2*context_size*embd_size, hidden_size),
        #     nn.ReLU(),
        #     nn.Linear(hidden_size, vocab_size),
        #     nn.LogSoftmax()
        # )
        self.Embd = nn.Embedding(vocab_size, embd_size)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        self.logsoftmax = nn.LogSoftmax()
        
         
    def forward(self, inputs):
        #TODO implement the forward of CBOW architecture
        # output = self.Embd(inputs)
        # output = output.view(output.shape[0],-1)
        # output = self.linear1(output)
        # output = self.relu(output)
        # output = self.linear2(output)
        # output = self.logsoftmax(output)
        # return output

        #########
        embedding = self.Embd(inputs).view((1, -1))
        #print(embedding.shape)
        output = self.linear1(embedding)
        #print(output.shape)
        output = self.relu(output)
        output = self.linear2(output)
        #print(output.shape)
        output = self.logsoftmax(output)
        return output

        
        # raise NotImplementedError

# %%
def train_cbow(train_data,
               test_data,
               model=None,
               n_epoch=5,
               embd_size=100,
               learning_rate=0.01,
               context_size=CONTEXT_SIZE,
               batch_size=1000,
               hidden_size=64,
               print_every=5000,
               random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Batch size
    batch_size = min(batch_size, len(train_data))
    ## Initialize New Model if Not Using Existing
    if model is None:
        model = CBOW(vocab_size, embd_size, context_size, hidden_size)
    ## GPU
    gpu_avail = torch.cuda.is_available()
    if gpu_avail:
        model = model.cuda()
    ## Show the Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate loss function
    loss_fn = nn.NLLLoss()
    ## Cache for Loss Values
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        model.train()
        count = 0
        for batch, (context, target) in enumerate(get_cbow_batches(train_data, batch_size)):
            ##TODO implement training procedure for CBOW
            #
          
            context = context.cuda()
            target = target.cuda()
            
            model.zero_grad()
            loss = 0
            for i in range(context.shape[0]):
              count += 1
              log_probs = model(context[i])
              loss += loss_fn(log_probs,  target[i])
            #

            loss.backward()
            optimizer.step()
        
            total_loss += loss.item()
            
            if print_every is not None and (batch + 1) % print_every == 0:
                print("Epoch {} || batch {} || Loss: {:.4f}".format(epoch+1, batch+1, total_loss / (batch+1)))
        
        model.eval()
        ##TODO Compute Loss on Test and Training Data
        train_loss = total_loss / count
        test_loss = 0
        count_test = 0
        for batch, (context, target) in enumerate(get_cbow_batches(test_data, batch_size)):
            ##TODO implement training procedure for CBOW
            
            #
            context = context.cuda()
            target = target.cuda()        
            loss = 0
            for i in range(context.shape[0]):
              count_test +=1 
              log_probs = model(context[i])
              loss += loss_fn(log_probs,  target[i])
            #
        
            test_loss += loss.item()

        test_loss = test_loss / count_test

        print("Epoch {}/{} || Train Loss: {:.4f} || Test Loss: {:.4f}".format(epoch+1, n_epoch, train_loss, test_loss))
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete.")
    return model, losses, test_losses

# %% [markdown]
# **For large dataset**

# %%
## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch= 100, #20,
                                     embd_size=300,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=1000,
                                     learning_rate=0.01,
                                     hidden_size=128,
                                     print_every=100)
# Out:
# CBOW(
#   (Embd): Embedding(55170, 300)
#   (linear1): Linear(in_features=1200, out_features=128, bias=True)
#   (relu): ReLU()
#   (linear2): Linear(in_features=128, out_features=55170, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )
# Epoch 1/100 || Train Loss: 10.9482 || Test Loss: 10.9121
# Epoch 2/100 || Train Loss: 10.4240 || Test Loss: 10.9932
# Epoch 3/100 || Train Loss: 9.5656 || Test Loss: 11.3231
# Epoch 4/100 || Train Loss: 8.5437 || Test Loss: 11.6399
# Epoch 5/100 || Train Loss: 7.6235 || Test Loss: 12.2266
# Epoch 6/100 || Train Loss: 6.4692 || Test Loss: 13.9679
# Epoch 7/100 || Train Loss: 5.7405 || Test Loss: 14.9110
# Epoch 8/100 || Train Loss: 4.8209 || Test Loss: 15.3429
# Epoch 9/100 || Train Loss: 3.7921 || Test Loss: 16.4389
# Epoch 10/100 || Train Loss: 3.2493 || Test Loss: 17.6287
# Epoch 11/100 || Train Loss: 2.9551 || Test Loss: 18.5320
# Epoch 12/100 || Train Loss: 2.7268 || Test Loss: 18.7867
# Epoch 13/100 || Train Loss: 2.5654 || Test Loss: 18.9217
# Epoch 14/100 || Train Loss: 2.4729 || Test Loss: 18.6645
# Epoch 15/100 || Train Loss: 2.4294 || Test Loss: 18.6509
# Epoch 16/100 || Train Loss: 2.4022 || Test Loss: 18.5771
# Epoch 17/100 || Train Loss: 2.3889 || Test Loss: 18.6355
# Epoch 18/100 || Train Loss: 2.3759 || Test Loss: 18.6522
# Epoch 19/100 || Train Loss: 2.3646 || Test Loss: 18.6538
# Epoch 20/100 || Train Loss: 2.3568 || Test Loss: 18.6854
# Epoch 21/100 || Train Loss: 2.3460 || Test Loss: 18.7726
# Epoch 22/100 || Train Loss: 2.3412 || Test Loss: 18.9129
# Epoch 23/100 || Train Loss: 2.3314 || Test Loss: 18.9026
# Epoch 24/100 || Train Loss: 2.3243 || Test Loss: 18.8402
# Epoch 25/100 || Train Loss: 2.3204 || Test Loss: 18.9758
# Epoch 26/100 || Train Loss: 2.3144 || Test Loss: 18.9791
# Epoch 27/100 || Train Loss: 2.3077 || Test Loss: 19.0296
# Epoch 28/100 || Train Loss: 2.3038 || Test Loss: 19.1329
# Epoch 29/100 || Train Loss: 2.2989 || Test Loss: 19.1839
# Epoch 30/100 || Train Loss: 2.2942 || Test Loss: 19.2395
# Epoch 31/100 || Train Loss: 2.2906 || Test Loss: 19.2921
# Epoch 32/100 || Train Loss: 2.2863 || Test Loss: 19.3473
# Epoch 33/100 || Train Loss: 2.2816 || Test Loss: 19.3269
# Epoch 34/100 || Train Loss: 2.2780 || Test Loss: 19.3851
# Epoch 35/100 || Train Loss: 2.2738 || Test Loss: 19.4430
# Epoch 36/100 || Train Loss: 2.2708 || Test Loss: 19.5864
# Epoch 37/100 || Train Loss: 2.2674 || Test Loss: 19.5573
# Epoch 38/100 || Train Loss: 2.2641 || Test Loss: 19.6147
# Epoch 39/100 || Train Loss: 2.2607 || Test Loss: 19.6555
# Epoch 40/100 || Train Loss: 2.2569 || Test Loss: 19.6885
# Epoch 41/100 || Train Loss: 2.2549 || Test Loss: 19.7604
# Epoch 42/100 || Train Loss: 2.2514 || Test Loss: 19.8080
# Epoch 43/100 || Train Loss: 2.2479 || Test Loss: 19.8443
# Epoch 44/100 || Train Loss: 2.2457 || Test Loss: 19.9082
# Epoch 45/100 || Train Loss: 2.2481 || Test Loss: 19.9284
# Epoch 46/100 || Train Loss: 2.2420 || Test Loss: 19.9671
# Epoch 47/100 || Train Loss: 2.2385 || Test Loss: 19.9717
# Epoch 48/100 || Train Loss: 2.2362 || Test Loss: 20.0577
# Epoch 49/100 || Train Loss: 2.2328 || Test Loss: 20.0649
# Epoch 50/100 || Train Loss: 2.2300 || Test Loss: 20.1020
# Epoch 51/100 || Train Loss: 2.2281 || Test Loss: 20.1670
# Epoch 52/100 || Train Loss: 2.2256 || Test Loss: 20.1994
# Epoch 53/100 || Train Loss: 2.2236 || Test Loss: 20.2738
# Epoch 54/100 || Train Loss: 2.2208 || Test Loss: 20.2608
# Epoch 55/100 || Train Loss: 2.2184 || Test Loss: 20.3073
# Epoch 56/100 || Train Loss: 2.2164 || Test Loss: 20.3446
# Epoch 57/100 || Train Loss: 2.2139 || Test Loss: 20.3765
# Epoch 58/100 || Train Loss: 2.2122 || Test Loss: 20.4265
# Epoch 59/100 || Train Loss: 2.2094 || Test Loss: 20.4718
# Epoch 60/100 || Train Loss: 2.2081 || Test Loss: 20.5210
# Epoch 61/100 || Train Loss: 2.2057 || Test Loss: 20.5597
# Epoch 62/100 || Train Loss: 2.2043 || Test Loss: 20.5489
# Epoch 63/100 || Train Loss: 2.2018 || Test Loss: 20.5737
# Epoch 64/100 || Train Loss: 2.2000 || Test Loss: 20.6190
# Epoch 65/100 || Train Loss: 2.1981 || Test Loss: 20.6483
# Epoch 66/100 || Train Loss: 2.1962 || Test Loss: 20.7253
# Epoch 67/100 || Train Loss: 2.1943 || Test Loss: 20.7028
# Epoch 68/100 || Train Loss: 2.1928 || Test Loss: 20.8072
# Epoch 69/100 || Train Loss: 2.1906 || Test Loss: 20.8219
# Epoch 70/100 || Train Loss: 2.1893 || Test Loss: 20.8360
# Epoch 71/100 || Train Loss: 2.1875 || Test Loss: 20.8717
# Epoch 72/100 || Train Loss: 2.1856 || Test Loss: 20.9159
# Epoch 73/100 || Train Loss: 2.1843 || Test Loss: 20.9500
# Epoch 74/100 || Train Loss: 2.1825 || Test Loss: 20.9698
# Epoch 75/100 || Train Loss: 2.1811 || Test Loss: 21.0128
# Epoch 76/100 || Train Loss: 2.1793 || Test Loss: 21.0334
# Epoch 77/100 || Train Loss: 2.1779 || Test Loss: 21.0713
# Epoch 78/100 || Train Loss: 2.1768 || Test Loss: 21.1270
# Epoch 79/100 || Train Loss: 2.1750 || Test Loss: 21.0968
# Epoch 80/100 || Train Loss: 2.1733 || Test Loss: 21.1483
# Epoch 81/100 || Train Loss: 2.1720 || Test Loss: 21.2017
# Epoch 82/100 || Train Loss: 2.1707 || Test Loss: 21.2073
# Epoch 83/100 || Train Loss: 2.1694 || Test Loss: 21.2418
# Epoch 84/100 || Train Loss: 2.1681 || Test Loss: 21.2570
# Epoch 85/100 || Train Loss: 2.1663 || Test Loss: 21.3097
# Epoch 86/100 || Train Loss: 2.1650 || Test Loss: 21.3111
# Epoch 87/100 || Train Loss: 2.1635 || Test Loss: 21.3856
# Epoch 88/100 || Train Loss: 2.1626 || Test Loss: 21.3658
# Epoch 89/100 || Train Loss: 2.1612 || Test Loss: 21.3401
# Epoch 90/100 || Train Loss: 2.1598 || Test Loss: 21.4557
# Epoch 91/100 || Train Loss: 2.1589 || Test Loss: 21.4498
# Epoch 92/100 || Train Loss: 2.1571 || Test Loss: 21.5073
# Epoch 93/100 || Train Loss: 2.1564 || Test Loss: 21.5516
# Epoch 94/100 || Train Loss: 2.1550 || Test Loss: 21.5898
# Epoch 95/100 || Train Loss: 2.1538 || Test Loss: 21.6104
# Epoch 96/100 || Train Loss: 2.1523 || Test Loss: 21.6307
# Epoch 97/100 || Train Loss: 2.1516 || Test Loss: 21.6294
# Epoch 98/100 || Train Loss: 2.1503 || Test Loss: 21.6528
# Epoch 99/100 || Train Loss: 2.1491 || Test Loss: 21.6731
# Epoch 100/100 || Train Loss: 2.1480 || Test Loss: 21.7338
# Training Complete.

# %%
## Test Predictive Accuracy
def test_cbow(test_data, model, sample_size=None, seed=42, use_gpu=False):
    ## Random State
    np.random.seed(seed)
    ## Count Correct Answers
    correct_ct = 0
    ## Downsample if Desired (To Save Time)
    if sample_size is None:
        sample = test_data
    else:
        sample = np.random.choice(len(test_data), sample_size, replace=False)
        sample = [test_data[s] for s in sample]
    ## Evaluate
    model.eval()
    for ctx_var, target in get_cbow_batches(sample, 1):
        if use_gpu:
            ctx_var = ctx_var.cuda()
        model.zero_grad()
        log_probs = model(ctx_var)
        if use_gpu:
            log_probs = log_probs.cpu()
        #_, predicted = torch.max(log_probs[0], 1)
        # if torch.eq(predicted, target[0]):
        #     correct_ct += 1
        predict = torch.argmax(log_probs).item()
        if predict == target[0].item():
          correct_ct += 1
            
    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(sample)*100, correct_ct, len(sample)))

test_cbow(cbow_train, cbow_model, sample_size=min(5000, len(cbow_train)), use_gpu=torch.cuda.is_available())
test_cbow(cbow_test, cbow_model, sample_size=min(5000, len(cbow_test)), use_gpu=torch.cuda.is_available())
# Out:
# Accuracy: 78.3% (3915/5000)
# Accuracy: 5.4% (272/5000)

# %%
showPlot('CBOW Losses',cbow_losses,cbow_test_losses)

# %% [markdown]
# **For small dataset**

# %%
## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch= 1000, #20,
                                     embd_size=300,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=1000,
                                     learning_rate=0.01,
                                     hidden_size=128,
                                     print_every=100)
# Out:
# CBOW(
#   (Embd): Embedding(435, 300)
#   (linear1): Linear(in_features=1200, out_features=128, bias=True)
#   (relu): ReLU()
#   (linear2): Linear(in_features=128, out_features=435, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )
# Epoch 1/1000 || Train Loss: 6.0835 || Test Loss: 4.3173
# Epoch 2/1000 || Train Loss: 5.4359 || Test Loss: 6.2454
# Epoch 3/1000 || Train Loss: 6.8051 || Test Loss: 8.4785
# Epoch 4/1000 || Train Loss: 8.6989 || Test Loss: 6.9369
# Epoch 5/1000 || Train Loss: 6.8795 || Test Loss: 3.7070
# Epoch 6/1000 || Train Loss: 3.6727 || Test Loss: 2.3442
# Epoch 7/1000 || Train Loss: 2.3614 || Test Loss: 1.7106
# Epoch 8/1000 || Train Loss: 1.7407 || Test Loss: 1.4128
# Epoch 9/1000 || Train Loss: 1.4142 || Test Loss: 1.1170
# Epoch 10/1000 || Train Loss: 1.1290 || Test Loss: 0.9678
# Epoch 11/1000 || Train Loss: 0.9747 || Test Loss: 0.8472
# Epoch 12/1000 || Train Loss: 0.8639 || Test Loss: 0.6513
# Epoch 13/1000 || Train Loss: 0.6752 || Test Loss: 0.5429
# Epoch 14/1000 || Train Loss: 0.5495 || Test Loss: 0.4272
# Epoch 15/1000 || Train Loss: 0.4712 || Test Loss: 0.3590
# Epoch 16/1000 || Train Loss: 0.3588 || Test Loss: 0.3028
# Epoch 17/1000 || Train Loss: 0.3044 || Test Loss: 0.2815
# Epoch 18/1000 || Train Loss: 0.2842 || Test Loss: 0.2447
# Epoch 19/1000 || Train Loss: 0.2450 || Test Loss: 0.2286
# Epoch 20/1000 || Train Loss: 0.2321 || Test Loss: 0.2154
# Epoch 21/1000 || Train Loss: 0.2162 || Test Loss: 0.1999
# Epoch 22/1000 || Train Loss: 0.1996 || Test Loss: 0.1855
# Epoch 23/1000 || Train Loss: 0.1854 || Test Loss: 0.1620
# Epoch 24/1000 || Train Loss: 0.1675 || Test Loss: 0.1374
# Epoch 25/1000 || Train Loss: 0.1436 || Test Loss: 0.1400
# Epoch 26/1000 || Train Loss: 0.1430 || Test Loss: 0.1169
# Epoch 27/1000 || Train Loss: 0.1177 || Test Loss: 0.1077
# Epoch 28/1000 || Train Loss: 0.1078 || Test Loss: 0.1005
# Epoch 29/1000 || Train Loss: 0.1012 || Test Loss: 0.0951
# Epoch 30/1000 || Train Loss: 0.0951 || Test Loss: 0.0893
# Epoch 31/1000 || Train Loss: 0.0892 || Test Loss: 0.0842
# Epoch 32/1000 || Train Loss: 0.0840 || Test Loss: 0.0793
# Epoch 33/1000 || Train Loss: 0.0790 || Test Loss: 0.0746
# Epoch 34/1000 || Train Loss: 0.0745 || Test Loss: 0.0701
# Epoch 35/1000 || Train Loss: 0.0708 || Test Loss: 0.0664
# Epoch 36/1000 || Train Loss: 0.0663 || Test Loss: 0.0616
# Epoch 37/1000 || Train Loss: 0.0614 || Test Loss: 0.0570
# Epoch 38/1000 || Train Loss: 0.0595 || Test Loss: 0.0536
# Epoch 39/1000 || Train Loss: 0.0544 || Test Loss: 0.0504
# Epoch 40/1000 || Train Loss: 0.0506 || Test Loss: 0.0467
# Epoch 41/1000 || Train Loss: 0.0477 || Test Loss: 0.0442
# Epoch 42/1000 || Train Loss: 0.0444 || Test Loss: 0.0411
# Epoch 43/1000 || Train Loss: 0.0409 || Test Loss: 0.0387
# Epoch 44/1000 || Train Loss: 0.0398 || Test Loss: 0.0367
# Epoch 45/1000 || Train Loss: 0.0391 || Test Loss: 0.0352
# Epoch 46/1000 || Train Loss: 0.0349 || Test Loss: 0.0327
# Epoch 47/1000 || Train Loss: 0.0339 || Test Loss: 0.0298
# Epoch 48/1000 || Train Loss: 0.0296 || Test Loss: 0.0271
# Epoch 49/1000 || Train Loss: 0.0282 || Test Loss: 0.0253
# Epoch 50/1000 || Train Loss: 0.0261 || Test Loss: 0.0247
# Epoch 51/1000 || Train Loss: 0.0247 || Test Loss: 0.0223
# Epoch 52/1000 || Train Loss: 0.0222 || Test Loss: 0.0211
# Epoch 53/1000 || Train Loss: 0.0211 || Test Loss: 0.0198
# Epoch 54/1000 || Train Loss: 0.0196 || Test Loss: 0.0187
# Epoch 55/1000 || Train Loss: 0.0187 || Test Loss: 0.0175
# Epoch 56/1000 || Train Loss: 0.0190 || Test Loss: 0.0172
# Epoch 57/1000 || Train Loss: 0.0173 || Test Loss: 0.0156
# Epoch 58/1000 || Train Loss: 0.0156 || Test Loss: 0.0146
# Epoch 59/1000 || Train Loss: 0.0160 || Test Loss: 0.0138
# Epoch 60/1000 || Train Loss: 0.0138 || Test Loss: 0.0126
# Epoch 61/1000 || Train Loss: 0.0127 || Test Loss: 0.0118
# Epoch 62/1000 || Train Loss: 0.0119 || Test Loss: 0.0112
# Epoch 63/1000 || Train Loss: 0.0111 || Test Loss: 0.0107
# Epoch 64/1000 || Train Loss: 0.0107 || Test Loss: 0.0102
# Epoch 65/1000 || Train Loss: 0.0117 || Test Loss: 0.0104
# Epoch 66/1000 || Train Loss: 0.0104 || Test Loss: 0.0097
# Epoch 67/1000 || Train Loss: 0.0097 || Test Loss: 0.0094
# Epoch 68/1000 || Train Loss: 0.0094 || Test Loss: 0.0091
# Epoch 69/1000 || Train Loss: 0.0116 || Test Loss: 0.0096
# Epoch 70/1000 || Train Loss: 0.0096 || Test Loss: 0.0088
# Epoch 71/1000 || Train Loss: 0.0088 || Test Loss: 0.0085
# Epoch 72/1000 || Train Loss: 0.0085 || Test Loss: 0.0083
# Epoch 73/1000 || Train Loss: 0.0083 || Test Loss: 0.0081
# Epoch 74/1000 || Train Loss: 0.0081 || Test Loss: 0.0079
# Epoch 75/1000 || Train Loss: 0.0079 || Test Loss: 0.0077
# Epoch 76/1000 || Train Loss: 0.0077 || Test Loss: 0.0076
# Epoch 77/1000 || Train Loss: 0.0076 || Test Loss: 0.0075
# Epoch 78/1000 || Train Loss: 0.0074 || Test Loss: 0.0073
# Epoch 79/1000 || Train Loss: 0.0073 || Test Loss: 0.0072
# Epoch 80/1000 || Train Loss: 0.0086 || Test Loss: 0.0076
# Epoch 81/1000 || Train Loss: 0.0076 || Test Loss: 0.0071
# Epoch 82/1000 || Train Loss: 0.0085 || Test Loss: 0.0074
# Epoch 83/1000 || Train Loss: 0.0074 || Test Loss: 0.0069
# Epoch 84/1000 || Train Loss: 0.0069 || Test Loss: 0.0067
# Epoch 85/1000 || Train Loss: 0.0067 || Test Loss: 0.0066
# Epoch 86/1000 || Train Loss: 0.0066 || Test Loss: 0.0065
# Epoch 87/1000 || Train Loss: 0.0065 || Test Loss: 0.0064
# Epoch 88/1000 || Train Loss: 0.0077 || Test Loss: 0.0067
# Epoch 89/1000 || Train Loss: 0.0067 || Test Loss: 0.0063
# Epoch 90/1000 || Train Loss: 0.0081 || Test Loss: 0.0067
# Epoch 91/1000 || Train Loss: 0.0067 || Test Loss: 0.0062
# Epoch 92/1000 || Train Loss: 0.0062 || Test Loss: 0.0061
# Epoch 134/1000 || Train Loss: 0.0045 || Test Loss: 0.0045
# Epoch 135/1000 || Train Loss: 0.0055 || Test Loss: 0.0047
# Epoch 136/1000 || Train Loss: 0.0053 || Test Loss: 0.0046
# Epoch 137/1000 || Train Loss: 0.0046 || Test Loss: 0.0045
# Epoch 138/1000 || Train Loss: 0.0045 || Test Loss: 0.0044
# Epoch 139/1000 || Train Loss: 0.0063 || Test Loss: 0.0048
# Epoch 140/1000 || Train Loss: 0.0057 || Test Loss: 0.0046
# Epoch 141/1000 || Train Loss: 0.0054 || Test Loss: 0.0046
# Epoch 142/1000 || Train Loss: 0.0046 || Test Loss: 0.0044
# Epoch 143/1000 || Train Loss: 0.0053 || Test Loss: 0.0045
# Epoch 144/1000 || Train Loss: 0.0045 || Test Loss: 0.0044
# Epoch 145/1000 || Train Loss: 0.0052 || Test Loss: 0.0045
# Epoch 146/1000 || Train Loss: 0.0053 || Test Loss: 0.0045
# Epoch 147/1000 || Train Loss: 0.0052 || Test Loss: 0.0044
# Epoch 148/1000 || Train Loss: 0.0050 || Test Loss: 0.0044
# Epoch 149/1000 || Train Loss: 0.0044 || Test Loss: 0.0043
# Epoch 150/1000 || Train Loss: 0.0043 || Test Loss: 0.0042
# Epoch 151/1000 || Train Loss: 0.0042 || Test Loss: 0.0042
# Epoch 152/1000 || Train Loss: 0.0059 || Test Loss: 0.0045
# Epoch 153/1000 || Train Loss: 0.0045 || Test Loss: 0.0042
# Epoch 154/1000 || Train Loss: 0.0042 || Test Loss: 0.0042
# Epoch 155/1000 || Train Loss: 0.0057 || Test Loss: 0.0044
# Epoch 156/1000 || Train Loss: 0.0044 || Test Loss: 0.0042
# Epoch 157/1000 || Train Loss: 0.0042 || Test Loss: 0.0042
# Epoch 158/1000 || Train Loss: 0.0042 || Test Loss: 0.0041
# Epoch 159/1000 || Train Loss: 0.0049 || Test Loss: 0.0042
# Epoch 160/1000 || Train Loss: 0.0042 || Test Loss: 0.0041
# Epoch 161/1000 || Train Loss: 0.0048 || Test Loss: 0.0042
# Epoch 162/1000 || Train Loss: 0.0042 || Test Loss: 0.0041
# Epoch 163/1000 || Train Loss: 0.0041 || Test Loss: 0.0041
# Epoch 164/1000 || Train Loss: 0.0048 || Test Loss: 0.0042
# Epoch 165/1000 || Train Loss: 0.0042 || Test Loss: 0.0040
# Epoch 166/1000 || Train Loss: 0.0040 || Test Loss: 0.0040
# Epoch 167/1000 || Train Loss: 0.0040 || Test Loss: 0.0040
# Epoch 168/1000 || Train Loss: 0.0040 || Test Loss: 0.0040
# Epoch 169/1000 || Train Loss: 0.0040 || Test Loss: 0.0040
# Epoch 170/1000 || Train Loss: 0.0040 || Test Loss: 0.0040
# Epoch 171/1000 || Train Loss: 0.0050 || Test Loss: 0.0042
# Epoch 172/1000 || Train Loss: 0.0051 || Test Loss: 0.0041
# Epoch 173/1000 || Train Loss: 0.0050 || Test Loss: 0.0041
# Epoch 174/1000 || Train Loss: 0.0041 || Test Loss: 0.0040
# Epoch 297/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 298/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 299/1000 || Train Loss: 0.0038 || Test Loss: 0.0033
# Epoch 300/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 301/1000 || Train Loss: 0.0041 || Test Loss: 0.0034
# Epoch 302/1000 || Train Loss: 0.0034 || Test Loss: 0.0033
# Epoch 303/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 304/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 305/1000 || Train Loss: 0.0039 || Test Loss: 0.0033
# Epoch 306/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 307/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 308/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 309/1000 || Train Loss: 0.0039 || Test Loss: 0.0033
# Epoch 310/1000 || Train Loss: 0.0041 || Test Loss: 0.0034
# Epoch 311/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 312/1000 || Train Loss: 0.0038 || Test Loss: 0.0033
# Epoch 313/1000 || Train Loss: 0.0033 || Test Loss: 0.0033
# Epoch 314/1000 || Train Loss: 0.0038 || Test Loss: 0.0033
# Epoch 315/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 316/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 317/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 318/1000 || Train Loss: 0.0044 || Test Loss: 0.0034
# Epoch 319/1000 || Train Loss: 0.0034 || Test Loss: 0.0032
# Epoch 320/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 321/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 322/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 323/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 324/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 325/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 326/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 327/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 328/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 329/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 330/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 331/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 332/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 333/1000 || Train Loss: 0.0038 || Test Loss: 0.0033
# Epoch 334/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 335/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 336/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 337/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 338/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 339/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 340/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 341/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 342/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 343/1000 || Train Loss: 0.0038 || Test Loss: 0.0032
# Epoch 344/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 345/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 346/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 347/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 348/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 349/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 350/1000 || Train Loss: 0.0040 || Test Loss: 0.0033
# Epoch 351/1000 || Train Loss: 0.0033 || Test Loss: 0.0032
# Epoch 352/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 353/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 354/1000 || Train Loss: 0.0032 || Test Loss: 0.0032
# Epoch 355/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 356/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 357/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 358/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 359/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 360/1000 || Train Loss: 0.0039 || Test Loss: 0.0032
# Epoch 361/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 362/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 363/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 364/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 365/1000 || Train Loss: 0.0038 || Test Loss: 0.0032
# Epoch 366/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 367/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 368/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 369/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 370/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 371/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 372/1000 || Train Loss: 0.0038 || Test Loss: 0.0032
# Epoch 373/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 374/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 375/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 376/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 377/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 378/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 379/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 380/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 381/1000 || Train Loss: 0.0039 || Test Loss: 0.0032
# Epoch 382/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 383/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 384/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 385/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 386/1000 || Train Loss: 0.0037 || Test Loss: 0.0032
# Epoch 387/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 388/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 389/1000 || Train Loss: 0.0036 || Test Loss: 0.0031
# Epoch 390/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 391/1000 || Train Loss: 0.0036 || Test Loss: 0.0031
# Epoch 392/1000 || Train Loss: 0.0039 || Test Loss: 0.0032
# Epoch 393/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 394/1000 || Train Loss: 0.0036 || Test Loss: 0.0031
# Epoch 395/1000 || Train Loss: 0.0038 || Test Loss: 0.0032
# Epoch 396/1000 || Train Loss: 0.0032 || Test Loss: 0.0031
# Epoch 397/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch 398/1000 || Train Loss: 0.0036 || Test Loss: 0.0031
# Epoch 399/1000 || Train Loss: 0.0031 || Test Loss: 0.0031
# Epoch
1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 556/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 557/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 558/1000 || Train Loss: 0.0034 || Test Loss: 0.0030
# Epoch 559/1000 || Train Loss: 0.0030 || Test Loss: 0.0029
# Epoch 560/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 561/1000 || Train Loss: 0.0035 || Test Loss: 0.0030
# Epoch 562/1000 || Train Loss: 0.0040 || Test Loss: 0.0030
# Epoch 563/1000 || Train Loss: 0.0034 || Test Loss: 0.0030
# Epoch 564/1000 || Train Loss: 0.0034 || Test Loss: 0.0030
# Epoch 565/1000 || Train Loss: 0.0030 || Test Loss: 0.0029
# Epoch 566/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 567/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 568/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 569/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 570/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 571/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 572/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 573/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 574/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 575/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 576/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 577/1000 || Train Loss: 0.0035 || Test Loss: 0.0030
# Epoch 578/1000 || Train Loss: 0.0030 || Test Loss: 0.0029
# Epoch 579/1000 || Train Loss: 0.0035 || Test Loss: 0.0029
# Epoch 580/1000 || Train Loss: 0.0035 || Test Loss: 0.0029
# Epoch 581/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 582/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 583/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 584/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 585/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 586/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 587/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 588/1000 || Train Loss: 0.0035 || Test Loss: 0.0029
# Epoch 589/1000 || Train Loss: 0.0035 || Test Loss: 0.0029
# Epoch 590/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 591/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 592/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 593/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 594/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 595/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 596/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 597/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 598/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 599/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 600/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 601/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 602/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 603/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 604/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 605/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 606/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 607/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 608/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 609/1000 || Train Loss: 0.0040 || Test Loss: 0.0030
# Epoch 610/1000 || Train Loss: 0.0030 || Test Loss: 0.0029
# Epoch 611/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 612/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 613/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 614/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 615/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 616/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 617/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 618/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 619/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 620/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 621/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 622/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 623/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 624/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 625/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 626/1000 || Train Loss: 0.0035 || Test Loss: 0.0029
# Epoch 627/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 628/1000 || Train Loss: 0.0039 || Test Loss: 0.0029
# Epoch 629/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 630/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 631/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 632/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 633/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 634/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 635/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 636/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 637/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 638/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 639/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 640/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 641/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 642/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 643/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 644/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 645/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 646/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 647/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 648/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 649/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 650/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 651/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 652/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 653/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 654/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 655/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 656/1000 || Train Loss: 0.0040 || Test Loss: 0.0029
# Epoch 657/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 658/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 659/1000 || Train Loss: 0.0037 || Test Loss: 0.0029
# Epoch 660/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 661/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 662/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 663/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 664/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 665/1000 || Train Loss: 0.0038 || Test Loss: 0.0029
# Epoch 666/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 667/1000 || Train Loss: 0.0029 || Test Loss: 0.0029
# Epoch 668/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 669/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 670/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 671/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 672/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 673/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 674/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 675/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 676/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 677/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 678/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 679/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 680/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 681/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 682/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 683/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 684/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 685/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 686/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 687/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 688/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 689/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 690/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 691/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 692/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 693/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 694/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 695/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 696/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 697/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 698/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 699/1000 || Train Loss: 0.0040 || Test Loss: 0.0029
# Epoch 700/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 701/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 702/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 703/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 704/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 705/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 706/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 707/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 708/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 709/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 710/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 711/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 712/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 713/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 714/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 715/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 716/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 717/1000 || Train Loss: 0.0039 || Test Loss: 0.0029
# Epoch 718/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 719/1000 || Train Loss: 0.0033 || Test Loss: 0.0029
# Epoch 720/1000 || Train Loss: 0.0029 || Test Loss: 0.0028
# Epoch 721/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 722/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 723/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 724/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 725/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 726/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 727/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 728/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 729/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 730/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 731/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 732/1000 || Train Loss: 0.0034 || Test Loss: 0.0029
# Epoch 733/1000 || Train Loss: 0.0033 || Test Loss: 0.0028
# Epoch 734/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 735/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 736/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 737/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 738/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 739/1000 || Train Loss: 0.0038 || Test Loss: 0.0029
# Epoch 740/1000 || Train Loss: 0.0033 || Test Loss: 0.0028
# Epoch
1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 953/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 954/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 955/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 956/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 957/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 958/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 959/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 960/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 961/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 962/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 963/1000 || Train Loss: 0.0033 || Test Loss: 0.0028
# Epoch 964/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 965/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 966/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 967/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 968/1000 || Train Loss: 0.0031 || Test Loss: 0.0028
# Epoch 969/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 970/1000 || Train Loss: 0.0028 || Test Loss: 0.0028
# Epoch 971/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 972/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 973/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 974/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 975/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 976/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 977/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 978/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 979/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 980/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 981/1000 || Train Loss: 0.0033 || Test Loss: 0.0028
# Epoch 982/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 983/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 984/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 985/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 986/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 987/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 988/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 989/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 990/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 991/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 992/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 993/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 994/1000 || Train Loss: 0.0038 || Test Loss: 0.0028
# Epoch 995/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 996/1000 || Train Loss: 0.0032 || Test Loss: 0.0028
# Epoch 997/1000 || Train Loss: 0.0028 || Test Loss: 0.0027
# Epoch 998/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 999/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Epoch 1000/1000 || Train Loss: 0.0027 || Test Loss: 0.0027
# Training Complete.

# %%
## Test Predictive Accuracy
def test_cbow(test_data, model, sample_size=None, seed=42, use_gpu=False):
    ## Random State
    np.random.seed(seed)
    ## Count Correct Answers
    correct_ct = 0
    ## Downsample if Desired (To Save Time)
    if sample_size is None:
        sample = test_data
    else:
        sample = np.random.choice(len(test_data), sample_size, replace=False)
        sample = [test_data[s] for s in sample]
    ## Evaluate
    model.eval()
    for ctx_var, target in get_cbow_batches(sample, 1):
        if use_gpu:
            ctx_var = ctx_var.cuda()
        model.zero_grad()
        log_probs = model(ctx_var)
        if use_gpu:
            log_probs = log_probs.cpu()
        #_, predicted = torch.max(log_probs[0], 1)
        # if torch.eq(predicted, target[0]):
        #     correct_ct += 1
        predict = torch.argmax(log_probs).item()
        if predict == target[0].item():
          correct_ct += 1
            
    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(sample)*100, correct_ct, len(sample)))

test_cbow(cbow_train, cbow_model, sample_size=min(5000, len(cbow_train)), use_gpu=torch.cuda.is_available())
test_cbow(cbow_test, cbow_model, sample_size=min(5000, len(cbow_test)), use_gpu=torch.cuda.is_available())
# Out:
# Accuracy: 99.8% (1088/1090)
# Accuracy: 99.8% (1088/1090)

# %%
showPlot('CBOW Losses',cbow_losses,cbow_test_losses)

# %% [markdown]
# ## Skip-gram Implementation

# %% [markdown]
# We've now trained an embedding using the continuous bag of words model. Below, we also show code for training the opposite model - the skipgram model - where you predict the context words based on a target word.
#
# Note how simple the SkipGram network is. There are no linear layers - just the embedding layer, and the training simply aims to maximize the dot product of embeddings of the target and embedding words.

# %% [markdown]
# #### Dataset Generation
#
# We provide the beginning of a function for generating the skipgram dataset. You need to implement negative sampling.

# %%
# Tuple of a word (the target) to a word (a context word)
def create_skipgram_dataset(documents, context_size, k_negative=5):
    data = []
    for document in documents:
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        for i in range(context_size, len(document) - context_size):
            for j in range(1, context_size+1):
                data.append((document[i], document[i-j], 1))
                data.append((document[i], document[i+j], 1))

            ##TODO: Implement negative sampling
            for _ in range(k_negative):
                A = [index for index in range(len(document)-1) if index not in [i-2,i-1,i,i+1,i+2]]
                if A != []:
                  A = np.random.choice(A)
                else:
                  A = 0
                data.append((document[i], document[A], 0))
                #raise NotImplementedError
    return data

## Create Datasets

CONTEXT_SIZE = 2 

skipgram_train = create_skipgram_dataset(documents_train, context_size=CONTEXT_SIZE, k_negative=5)
skipgram_test = create_skipgram_dataset(documents_test, context_size=CONTEXT_SIZE, k_negative=5)

## Show Samples
print('skipgram sample', skipgram_train[:10])
# Out:
# skipgram sample [('once', 'EOS', 1), ('once', 'upon', 1), ('once', 'EOS', 1), ('once', 'a', 1), ('once', 'word', 0), ('once', 'quoth', 0), ('once', 'of', 0), ('once', 'tell', 0), ('once', 'to', 0), ('upon', 'once', 1)]

# %%
## Create Batches
def get_sgram_batches(data, batch_size):
    """

    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        in_w, out_w, target = data[indice]
        in_w_var = torch.LongTensor([w2i[in_w]])
        out_w_var = torch.LongTensor([w2i[out_w]])
        target_t = torch.Tensor([target])
        current_batch.append((in_w_var, out_w_var, target_t))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_in_w_var = torch.stack([v[0] for v in current_batch])
            batch_out_w_var = torch.stack([v[1] for v in current_batch])
            batch_target = torch.stack([v[2] for v in current_batch])
            current_batch = []
            yield batch_in_w_var, batch_out_w_var, batch_target

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        #TODO implement layers shown in the picture above
        self.Embd = nn.Embedding(vocab_size, embd_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, focus, context):
        #TODO implement forward of SkipGram.
        focus = self.Embd(focus)
        context = self.Embd(context)
        output = torch.bmm(focus, context.transpose(1, 2))
        output = output.view(output.shape[0],1)
        return output

# %%
def train_skipgram(train_data,
                   test_data,
                   model=None,
                   n_epoch=30,
                   learning_rate=0.01,
                   batch_size=1,
                   embd_size=128,
                   print_every_step=None,
                   print_every_epoch=1,
                   random_seed=1):
    """
    
    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Initialize Model
    if model is None:
        model = SkipGram(vocab_size, embd_size)
    ## Put on GPU
    if torch.cuda.is_available():
        model = model.cuda()
    ## Show Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate Loss Function
    loss_fn = nn.MSELoss()
    ## Loss Cache
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        count = 0
        for step, (in_w_var, out_w_var, target_t) in enumerate(get_sgram_batches(train_data, batch_size)):
            #TODO implement training procedure for SkipGram
            count += 1
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()

            model.zero_grad()

            prediction = model(in_w_var,out_w_var)
            loss = loss_fn(prediction,  target_t)

            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            
            if print_every_step is not None and (step + 1) % print_every_step == 0:
                print("Epoch {} || Step {}/{} || Loss: {:.4f}".format(epoch+1, step+1, len(train_data), (total_loss / step+1)))
            
        if print_every_epoch is not None and (epoch + 1) % print_every_epoch == 0:
            print("Epoch {}/{} || Loss: {:.4f}".format(epoch+1, n_epoch, total_loss / (step + 1)))
        ##TODO Compute Losses
        train_loss = total_loss / count 
        test_loss = 0
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete")
    return model, losses

# %% [markdown]
# **For small dataset**

# %%
## Fit Model
sg_model, sg_losses = train_skipgram(skipgram_train,
                                     skipgram_test,
                                     n_epoch=1000,
                                     learning_rate=1,
                                     batch_size= len(skipgram_train),
                                     embd_size=128,
                                     print_every_step=None,
                                     print_every_epoch=10)
# Out:
# SkipGram(
#   (Embd): Embedding(435, 128)
#   (sigmoid): Sigmoid()
# )
# Epoch 10/1000 || Loss: 22.7848
# Epoch 20/1000 || Loss: 7.7556
# Epoch 30/1000 || Loss: 3.5238
# Epoch 40/1000 || Loss: 1.8811
# Epoch 50/1000 || Loss: 1.1300
# Epoch 60/1000 || Loss: 0.7468
# Epoch 70/1000 || Loss: 0.5338
# Epoch 80/1000 || Loss: 0.4067
# Epoch 90/1000 || Loss: 0.3260
# Epoch 100/1000 || Loss: 0.2721
# Epoch 110/1000 || Loss: 0.2343
# Epoch 120/1000 || Loss: 0.2069
# Epoch 130/1000 || Loss: 0.1863
# Epoch 140/1000 || Loss: 0.1705
# Epoch 150/1000 || Loss: 0.1579
# Epoch 160/1000 || Loss: 0.1478
# Epoch 170/1000 || Loss: 0.1394
# Epoch 180/1000 || Loss: 0.1325
# Epoch 190/1000 || Loss: 0.1266
# Epoch 200/1000 || Loss: 0.1216
# Epoch 210/1000 || Loss: 0.1173
# Epoch 220/1000 || Loss: 0.1135
# Epoch 230/1000 || Loss: 0.1102
# Epoch 240/1000 || Loss: 0.1073
# Epoch 250/1000 || Loss: 0.1047
# Epoch 260/1000 || Loss: 0.1024
# Epoch 270/1000 || Loss: 0.1003
# Epoch 280/1000 || Loss: 0.0984
# Epoch 290/1000 || Loss: 0.0967
# Epoch 300/1000 || Loss: 0.0951
# Epoch 310/1000 || Loss: 0.0936
# Epoch 320/1000 || Loss: 0.0923
# Epoch 330/1000 || Loss: 0.0911
# Epoch 340/1000 || Loss: 0.0899
# Epoch 350/1000 || Loss: 0.0889
# Epoch 360/1000 || Loss: 0.0879
# Epoch 370/1000 || Loss: 0.0870
# Epoch 380/1000 || Loss: 0.0861
# Epoch 390/1000 || Loss: 0.0853
# Epoch 400/1000 || Loss: 0.0845
# Epoch 410/1000 || Loss: 0.0838
# Epoch 420/1000 || Loss: 0.0831
# Epoch 430/1000 || Loss: 0.0825
# Epoch 440/1000 || Loss: 0.0819
# Epoch 450/1000 || Loss: 0.0813
# Epoch 460/1000 || Loss: 0.0807
# Epoch 470/1000 || Loss: 0.0802
# Epoch 480/1000 || Loss: 0.0797
# Epoch 490/1000 || Loss: 0.0792
# Epoch 500/1000 || Loss: 0.0787
# Epoch 510/1000 || Loss: 0.0783
# Epoch 520/1000 || Loss: 0.0779
# Epoch 530/1000 || Loss: 0.0774
# Epoch 540/1000 || Loss: 0.0771
# Epoch 550/1000 || Loss: 0.0767
# Epoch 560/1000 || Loss: 0.0763
# Epoch 570/1000 || Loss: 0.0759
# Epoch 580/1000 || Loss: 0.0756
# Epoch 590/1000 || Loss: 0.0753
# Epoch 600/1000 || Loss: 0.0749
# Epoch 610/1000 || Loss: 0.0746
# Epoch 620/1000 || Loss: 0.0743
# Epoch 630/1000 || Loss: 0.0740
# Epoch 640/1000 || Loss: 0.0737
# Epoch 650/1000 || Loss: 0.0735
# Epoch 660/1000 || Loss: 0.0732
# Epoch 670/1000 || Loss: 0.0729
# Epoch 680/1000 || Loss: 0.0727
# Epoch 690/1000 || Loss: 0.0724
# Epoch 700/1000 || Loss: 0.0722
# Epoch 710/1000 || Loss: 0.0719
# Epoch 720/1000 || Loss: 0.0717
# Epoch 730/1000 || Loss: 0.0715
# Epoch 740/1000 || Loss: 0.0712
# Epoch 750/1000 || Loss: 0.0710
# Epoch 760/1000 || Loss: 0.0708
# Epoch 770/1000 || Loss: 0.0706
# Epoch 780/1000 || Loss: 0.0704
# Epoch 790/1000 || Loss: 0.0702
# Epoch 800/1000 || Loss: 0.0700
# Epoch 810/1000 || Loss: 0.0698
# Epoch 820/1000 || Loss: 0.0696
# Epoch 830/1000 || Loss: 0.0694
# Epoch 840/1000 || Loss: 0.0692
# Epoch 850/1000 || Loss: 0.0691
# Epoch 860/1000 || Loss: 0.0689
# Epoch 870/1000 || Loss: 0.0687
# Epoch 880/1000 || Loss: 0.0685
# Epoch 890/1000 || Loss: 0.0684
# Epoch 900/1000 || Loss: 0.0682
# Epoch 910/1000 || Loss: 0.0680
# Epoch 920/1000 || Loss: 0.0679
# Epoch 930/1000 || Loss: 0.0677
# Epoch 940/1000 || Loss: 0.0676
# Epoch 950/1000 || Loss: 0.0674
# Epoch 960/1000 || Loss: 0.0673
# Epoch 970/1000 || Loss: 0.0671
# Epoch 980/1000 || Loss: 0.0670
# Epoch 990/1000 || Loss: 0.0669
# Epoch 1000/1000 || Loss: 0.0667
# Training Complete

# %%
## Plot Losses
showPlot('SkipGram Losses', sg_losses)

# %%
## Evaluate Accuracy
def test_skipgram(test_data, model):
    correct_ct = 0
    for in_w_var, out_w_var, target_t in get_sgram_batches(test_data, 1):

        if torch.cuda.is_available():
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()
        probs = model(in_w_var, out_w_var)
        predicted = (probs > 0.5)
        correct_ct += torch.sum(torch.eq(predicted[0], target_t))

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_skipgram(skipgram_train, sg_model)
test_skipgram(skipgram_test, sg_model)
# Out:
# Accuracy: 90.8% (8904/9810)
# Accuracy: 74.7% (7328/9810)

# %% [markdown]
# **For large-text**

# %%
## Fit Model
sg_model, sg_losses = train_skipgram(skipgram_train,
                                     skipgram_test,
                                     n_epoch=100,
                                     learning_rate=1,
                                     batch_size= len(skipgram_train),
                                     embd_size=128,
                                     print_every_step=None,
                                     print_every_epoch=1)
# Out:
# SkipGram(
#   (Embd): Embedding(55170, 128)
#   (sigmoid): Sigmoid()
# )
# Epoch 1/100 || Loss: 236.3069
# Epoch 2/100 || Loss: 147.2225
# Epoch 3/100 || Loss: 134.4423
# Epoch 4/100 || Loss: 131.3033
# Epoch 5/100 || Loss: 129.5928
# Epoch 6/100 || Loss: 128.1670
# Epoch 7/100 || Loss: 126.8311
# Epoch 8/100 || Loss: 125.5452
# Epoch 9/100 || Loss: 124.2990
# Epoch 10/100 || Loss: 123.0883
# Epoch 11/100 || Loss: 121.9107
# Epoch 12/100 || Loss: 120.7640
# Epoch 13/100 || Loss: 119.6465
# Epoch 14/100 || Loss: 118.5565
# Epoch 15/100 || Loss: 117.4925
# Epoch 16/100 || Loss: 116.4533
# Epoch 17/100 || Loss: 115.4375
# Epoch 18/100 || Loss: 114.4441
# Epoch 19/100 || Loss: 113.4720
# Epoch 20/100 || Loss: 112.5202
# Epoch 21/100 || Loss: 111.5879
# Epoch 22/100 || Loss: 110.6743
# Epoch 23/100 || Loss: 109.7785
# Epoch 24/100 || Loss: 108.8999
# Epoch 25/100 || Loss: 108.0377
# Epoch 26/100 || Loss: 107.1915
# Epoch 27/100 || Loss: 106.3605
# Epoch 28/100 || Loss: 105.5442
# Epoch 29/100 || Loss: 104.7421
# Epoch 30/100 || Loss: 103.9538
# Epoch 31/100 || Loss: 103.1786
# Epoch 32/100 || Loss: 102.4163
# Epoch 33/100 || Loss: 101.6664
# Epoch 34/100 || Loss: 100.9285
# Epoch 35/100 || Loss: 100.2023
# Epoch 36/100 || Loss: 99.4873
# Epoch 37/100 || Loss: 98.7833
# Epoch 38/100 || Loss: 98.0899
# Epoch 39/100 || Loss: 97.4068
# Epoch 40/100 || Loss: 96.7337
# Epoch 41/100 || Loss: 96.0704
# Epoch 42/100 || Loss: 95.4166
# Epoch 43/100 || Loss: 94.7721
# Epoch 44/100 || Loss: 94.1365
# Epoch 45/100 || Loss: 93.5096
# Epoch 46/100 || Loss: 92.8913
# Epoch 47/100 || Loss: 92.2814
# Epoch 48/100 || Loss: 91.6795
# Epoch 49/100 || Loss: 91.0855
# Epoch 50/100 || Loss: 90.4993
# Epoch 51/100 || Loss: 89.9206
# Epoch 52/100 || Loss: 89.3493
# Epoch 53/100 || Loss: 88.7852
# Epoch 54/100 || Loss: 88.2281
# Epoch 55/100 || Loss: 87.6779
# Epoch 56/100 || Loss: 87.1345
# Epoch 57/100 || Loss: 86.5976
# Epoch 58/100 || Loss: 86.0671
# Epoch 59/100 || Loss: 85.5429
# Epoch 60/100 || Loss: 85.0249
# Epoch 61/100 || Loss: 84.5129
# Epoch 62/100 || Loss: 84.0069
# Epoch 63/100 || Loss: 83.5066
# Epoch 64/100 || Loss: 83.0120
# Epoch 65/100 || Loss: 82.5230
# Epoch 66/100 || Loss: 82.0395
# Epoch 67/100 || Loss: 81.5612
# Epoch 68/100 || Loss: 81.0883
# Epoch 69/100 || Loss: 80.6204
# Epoch 70/100 || Loss: 80.1577
# Epoch 71/100 || Loss: 79.6998
# Epoch 72/100 || Loss: 79.2469
# Epoch 73/100 || Loss: 78.7987
# Epoch 74/100 || Loss: 78.3552
# Epoch 75/100 || Loss: 77.9163
# Epoch 76/100 || Loss: 77.4820
# Epoch 77/100 || Loss: 77.0520
# Epoch 78/100 || Loss: 76.6265
# Epoch 79/100 || Loss: 76.2052
# Epoch 80/100 || Loss: 75.7882
# Epoch 81/100 || Loss: 75.3753
# Epoch 82/100 || Loss: 74.9664
# Epoch 83/100 || Loss: 74.5616
# Epoch 84/100 || Loss: 74.1607
# Epoch 85/100 || Loss: 73.7637
# Epoch 86/100 || Loss: 73.3706
# Epoch 87/100 || Loss: 72.9811
# Epoch 88/100 || Loss: 72.5954
# Epoch 89/100 || Loss: 72.2133
# Epoch 90/100 || Loss: 71.8348
# Epoch 91/100 || Loss: 71.4598
# Epoch 92/100 || Loss: 71.0883
# Epoch 93/100 || Loss: 70.7202
# Epoch 94/100 || Loss: 70.3554
# Epoch 95/100 || Loss: 69.9940
# Epoch 96/100 || Loss: 69.6358
# Epoch 97/100 || Loss: 69.2808
# Epoch 98/100 || Loss: 68.9290
# Epoch 99/100 || Loss: 68.5804
# Epoch 100/100 || Loss: 68.2348
# Training Complete

# %%
## Plot Losses
showPlot('SkipGram Losses', sg_losses)

test_skipgram(skipgram_train, sg_model)
test_skipgram(skipgram_test, sg_model)
# Out:
# Accuracy: 59.7% (411242/689301)
# Accuracy: 59.5% (135202/227196)

# %% [markdown]
# ### Semantic Similarity
# You are asked to write 2 functions. The first function `get_similarity` takes two terms in the vocabulary as arguments and returns their semantic similarity (cosine similarity). The second function `show_similar_terms` takes as an argument a term in the vocabulary and shows the top_k most similar terms based on cosine similarity. Use your functions to evaluate similarity of words in the Raven (based on your trained model) and some general words in the pretrained corpus.
#
# *Note:* Typically, word embeddings are typically trained on much larger datasets than the ones we provide. You will not necessarily see interpretable similarities below. We are primarily interested in your implementation. Accordingly, we provide code that loads pretrained word embeddings learned using 27 billion tweets. Learn more here: https://nlp.stanford.edu/projects/glove/

# %%
## Load Pretrained Vectors
glove_vectors = gensim.downloader.load('glove-twitter-25')

## Extract Embeddings and Vocab
glove_vocab = glove_vectors.index2word ## Note: If this doesn't work because of version < 4.0, use .index_to_key
glove_w2i = {w : i for i, w in enumerate(glove_vocab)}
glove_i2w = {i : w for i, w in enumerate(glove_vocab)}

## Convert Embeddings
glove_embeddings = nn.Embedding(len(glove_vocab), 25)
glove_embeddings = glove_embeddings.from_pretrained(torch.Tensor(glove_vectors.vectors))

# %%
def get_similarity(embeddings,
                   w2i,
                   term1,
                   term2):
    """

    """
    ## Check Terms
    for term in [term1, term2]:
        if term not in w2i:
            raise KeyError(f"Term `{term}` not found")
    ## Get Indices
    term1_ind = torch.LongTensor([w2i[term1]])
    term2_ind = torch.LongTensor([w2i[term2]])
    ##TODO: Retrieve Embeddings and Compute Cosine Similarity
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    term1_ind = term1_ind.cuda()
    term2_ind = term2_ind.cuda()
    x = embeddings(term1_ind)
    y = embeddings(term2_ind)
    distance = cos(x,y).item()
    print(term1, term2, distance)

def show_similar_terms(embeddings, 
                       w2i,
                       i2w,
                       target_term,
                       top_k=10):
    """
    
    """
    ## Get Target Vector
    if target_term not in w2i:
        raise KeyError(f"Term `{target_term}` not in vocabulary")
    target_ind = torch.LongTensor([w2i[target_term]])
    target_ind = target_ind.cuda()
    ##TODO: Retrieve Embeddings for Target Term and Full Vocabulary
    ## Print out the top_k most similar terms based on cosine similarity
    x = embeddings(target_ind)
    dist = []
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)  
    for i in w2i:
      A = torch.LongTensor([w2i[i]])
      A = A.cuda()
      B = embeddings(A)
      distance = cos(x,B).item()
      dist.append( (A,distance))

    dist.sort(key = lambda x: -x[1])

    top_terms = [ i2w[i[0].item()] for i in dist[1:top_k+1]]

    print(top_terms)

# %% [markdown]
# #### Evaluation
#
# First, evaluate similarity for embeddings trained using The Raven snippet. Then evaluate similarity in the pretrained embeddings.

# %%
## Evaluation for The Raven embeddings
get_similarity(cbow_model.Embd, w2i, "raven","nevermore")
get_similarity(cbow_model.Embd, w2i, "raven", "door")
show_similar_terms(cbow_model.Embd, w2i, i2w, "raven")

## Evaluation for The Raven Skipgram embeddings
get_similarity(sg_model.Embd, w2i, "raven","nevermore")
get_similarity(sg_model.Embd, w2i, "raven", "door")
show_similar_terms(sg_model.Embd, w2i, i2w, "raven")
# Out:
# raven nevermore 0.0857040286064148
# raven door 0.058924026787281036
# ['hope', 'god', 'from', 'sign', 'him', 'beating', 'ah', 'is', 'rustling', 'the']
# raven nevermore 0.011956056579947472
# raven door -0.012028314173221588
# ['wished', 'faintly', 'feather', 'at', 'bust', 'gloated', 'our', 'syllable', 'again', 'forgiveness']

# %%
## Evaluation for Glove Embeddings
get_similarity(glove_embeddings, glove_w2i, "mouse","computer")
get_similarity(glove_embeddings, glove_w2i, "mouse","cat")
get_similarity(glove_embeddings, glove_w2i, "mouse","dog")
get_similarity(glove_embeddings, glove_w2i, "cat","dog")
show_similar_terms(glove_embeddings, glove_w2i, glove_i2w, "cat")
# Out:
# mouse computer 0.6954286694526672
# mouse cat 0.8381086587905884
# mouse dog 0.760636568069458
# cat dog 0.9590820670127869
# ['dog', 'monkey', 'bear', 'pet', 'girl', 'horse', 'kitty', 'puppy', 'hot', 'lady']
